# %%
import api_all as api
import imageio
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ModuleNotFoundError: No module named 'numpy.core._multiarray_umath'
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core.multiarray failed to import
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /anaconda3/envs/python36/lib/python3.6/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# SystemError: <class '_frozen_importlib._ModuleLockManager'> returned a result with an error set
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ...

# %%
img = imageio.imread("../data/RAW/QH/000_quang_hai.jpg")

# %%
bb = api.crop_face(img)

# %%
bb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9619a9b308cd> in <module>
# ----> 1 bb
#
# NameError: name 'bb' is not defined

# %%
vector = api.vectorizer("image_112.png", "image_160.png", "../models/model", "../keras-facenet/model/facenet_keras.h5")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-38b52db3954e> in <module>
# ----> 1 vector = api.vectorizer("image_112.png", "image_160.png", "../models/model", "../keras-facenet/model/facenet_keras.h5")
#
# ~/Desktop/Machine Learning/django/face_recognize_api/CMCAIContest_a70!13/server/api_all.py in vectorizer(image_112_path, image_160_path, model_mxnet_path, model_facenet_path)
#     146 def vectorizer(image_112_path, image_160_path, model_mxnet_path, model_facenet_path):
#     147     model_mxnet = get_model_mxnet(model_mxnet_path)
# --> 148     model_facenet = get_model_facenet(model_facenet_path)
#     149     img_test_path_mxnet = imageio.imread(image_112_path)
#     150     img_test_path_facenet = imageio.imread(image_160_path)
#
# ~/Desktop/Machine Learning/django/face_recognize_api/CMCAIContest_a70!13/server/api_all.py in get_model_facenet(model_path)
# ...

# %%
list_res = api.get_same_person(vector, "emb_vectors.pkl", threshold=1.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3a210754b762> in <module>
# ----> 1 list_res = api.get_same_person(vector, "emb_vectors.pkl", threshold=1.5)
#
# NameError: name 'vector' is not defined

# %%
len(list_res)
# Out:
# 74

# %%
import pickle 
l=pickle.load(open("emb_vectors.pkl", "rb"))

# %%
for i in range(0, len(l)):
    if l[i][0] == "PQH_0099_0.png":
        print(l[i])
# Out:
# ['PQH_0099_0.png', [204, 31, 290, 132], array([[ 7.71184713e-02,  2.46034209e-02, -2.67843921e-02,
#          9.09956321e-02,  9.49577335e-03,  3.93371470e-02,
#         -6.86448291e-02, -5.95559366e-02,  8.65810737e-03,
#         -8.85511935e-02, -6.94525391e-02, -4.64808568e-03,
#          1.87745262e-02, -4.16107848e-02,  3.56689580e-02,
#         -3.67344986e-03,  1.39930481e-02, -2.42086090e-02,
#          1.89427398e-02, -4.42722477e-02,  3.50336544e-02,
#          1.15032569e-02, -1.74574293e-02, -1.42962867e-02,
#         -6.80584041e-03,  3.16331238e-02, -2.78677326e-02,
#          2.33674832e-02, -5.55816479e-02, -8.13210458e-02,
#          1.66405756e-02, -4.21037003e-02, -1.89184211e-02,
#         -3.13074291e-02, -1.26520693e-02, -6.14961667e-04,
#          1.79138873e-02,  4.16816883e-02,  2.26548482e-02,
#          1.75539255e-02,  2.25655828e-02, -1.78657323e-02,
#          2.45905984e-02, -1.61960963e-02,  4.95490953e-02,
# ...

# %%
l[i]
# Out:
# ['Ray_Wasden_0001_0.png',
#  [57, 50, 182, 207],
#  array([[ 3.36704105e-02, -2.90177912e-02,  8.06729347e-02,
#           9.68540274e-03,  1.03935692e-03, -5.77191040e-02,
#           3.26930918e-02,  1.35409841e-02,  1.23156114e-02,
#          -2.54093818e-02,  5.16068079e-02,  2.12687030e-02,
#          -4.21678647e-04,  8.12302530e-02, -1.29751151e-03,
#          -6.82685673e-02, -3.34781641e-03,  3.45486067e-02,
#           1.16208550e-02, -1.58128906e-02, -5.99667756e-03,
#           4.61861826e-02, -9.27128345e-02,  2.62777358e-02,
#           3.79945785e-02,  4.79914509e-02, -4.83202375e-02,
#          -5.89823164e-02, -8.50934163e-02, -4.24273498e-02,
#          -2.10246108e-02,  5.31405956e-02,  4.58315536e-02,
#           9.64126512e-02, -9.26360115e-02, -6.60473332e-02,
#          -8.11841488e-02, -3.96929123e-02, -2.23235413e-02,
#           4.29352298e-02, -5.22444844e-02,  3.33363824e-02,
#           4.38109934e-02, -6.68002246e-03,  2.72347853e-02,
# ...
